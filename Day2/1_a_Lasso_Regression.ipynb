# %%
import pandas as pd
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression , Lasso, Ridge
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
boston = pd.read_csv('Boston.csv')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
a = [0.01,0.1,0.5,1,1.4,2,2.5]

# %%
X = boston.drop('medv', axis=1)
y = boston['medv']
X_train, X_test, Y_train , Y_test = train_test_split(X,y,test_size=0.3, random_state=24)

# %%
scores = []
for element in a:
    lasso = Lasso(alpha = element)
    lasso.fit(X_train,Y_train)
    y_pred = lasso.predict(X_test)
    # print(r2_score(Y_test,y_pred))
    scores.append(r2_score(Y_test,y_pred))

# %%
print("scores : ", scores)
print("Index of maximum r2_score",np.argmax(scores))
print("Maximum r2_score is : " , np.max(scores))
print("Minimum r2_Score is : ", np.min(scores))
print("Index of minimum r2_score : ", np.argmin(scores))
# Out:
# scores :  [0.7084666049270477, 0.6891238027018759, 0.6855353523161432, 0.669147589401661, 0.6474989201509055, 0.6197786590152295, 0.6000875677710251]
# Index of maximum r2_score 0
# Maximum r2_score is :  0.7084666049270477
# Minimum r2_Score is :  0.6000875677710251
# Index of minimum r2_score :  6

# %%
i_max = np.argmax(scores)
print("Best Alpha : ", a[i_max])
# Out:
# Best Alpha :  0.01

# %%
df2 = pd.read_csv('insurance.csv')

# %%
df2.shape
# Out:
# (1338, 7)

# %%
X = df2.drop('charges', axis = 1)
X_ohe = pd.get_dummies(X, drop_first=True)
X_ohe
y = df2['charges']
X_ohe.shape
# Out:
# (1338, 8)

# %%
y.shape
# Out:
# (1338,)

# %%
X_train,Y_train,X_test,Y_test = train_test_split(X_ohe,y,test_size=0.2,random_state=24)

# %%
x = [0.01,0.1,0.5,1,1.4,2,5]

# %%
for element in x:
    ridge = Ridge(alpha = element)
    ridge.fit(X_train,Y_train)
    y_pred = ridge.predict(X_test)
    print(r2_score(Y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 3
#       1 for element in x:
#       2     ridge = Ridge(alpha = element)
# ----> 3     ridge.fit(X_train,Y_train)
#       4     y_pred = ridge.predict(X_test)
#       5     print(r2_score(Y_test,y_pred))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:1167, in Ridge.fit(self, X, y, sample_weight)
#    1147 """Fit Ridge regression model.
#    1148
#    1149 Parameters
#    (...)
#    1164     Fitted estimator.
#    1165 """
#    1166 _accept_sparse = _get_valid_accept_sparse(sparse.issparse(X), self.solver)
# -> 1167 X, y = self._validate_data(
#    1168     X,
#    1169     y,
#    1170     accept_sparse=_accept_sparse,
#    1171     dtype=[np.float64, np.float32],
#    1172     multi_output=True,
#    1173     y_numeric=True,
#    1174 )
#    1175 return super().fit(X, y, sample_weight=sample_weight)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1281, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    (...)
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1281 check_consistent_length(X, y)
#    1283 return X, y
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1070, 268]
