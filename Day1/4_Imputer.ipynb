# %%
import pandas as pd

# %%
df = pd.read_csv('JobSalary2.csv')

# %%
df
# Out:
#    S_No  Computer  Marketing  Engineer
# 0     1      84.0       55.0        75
# 1     2      90.0       53.0        70
# 2     3      63.0        NaN        88
# 3     4       NaN       50.0        77
# 4     5      63.0       41.0        89
# 5     6      75.0       54.0        85
# 6     7       NaN       51.0        96
# 7     8      77.0       64.0       105

# %%
#Check for null values
df.isnull().sum()
# Out:
# S_No         0
# Computer     2
# Marketing    1
# Engineer     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
# data transformation class

# %% [markdown]
# Constant Strategy

# %%
imp = SimpleImputer(strategy='constant',fill_value=50).set_output(transform = 'pandas')
# Set_output will give output in data frame , otherwise its array
imp_data = imp.fit_transform(df)
type(imp_data)
imp_data
# Out:
#    S_No  Computer  Marketing  Engineer
# 0   1.0      84.0       55.0      75.0
# 1   2.0      90.0       53.0      70.0
# 2   3.0      63.0       50.0      88.0
# 3   4.0      50.0       50.0      77.0
# 4   5.0      63.0       41.0      89.0
# 5   6.0      75.0       54.0      85.0
# 6   7.0      50.0       51.0      96.0
# 7   8.0      77.0       64.0     105.0

# %% [markdown]
# Mean Strategy - when we fill nan datas with mean
#
# Median Strategy - when we fill nan datas with median

# %% [markdown]
# # Chemical Process Data

# %%
df1 = pd.read_csv('ChemicalProcess.csv')

# %%
df1
# Out:
#      Yield  BiologicalMaterial01  BiologicalMaterial02  BiologicalMaterial03  \
# 0    38.00                  6.25                 49.58                 56.97
# 1    42.44                  8.01                 60.97                 67.48
# 2    42.03                  8.01                 60.97                 67.48
# 3    41.42                  8.01                 60.97                 67.48
# 4    42.49                  7.47                 63.33                 72.25
# ..     ...                   ...                   ...                   ...
# 171  39.66                  6.71                 56.32                 66.19
# 172  39.68                  6.87                 56.74                 66.61
# 173  42.23                  7.50                 58.41                 68.30
# 174  38.48                  7.53                 58.36                 69.25
# 175  39.49                  7.53                 58.36                 69.25
#
# ...

# %%
df1.isnull().sum().sum()
# Out:
# 106

# %% [markdown]
# # Impute Mean

# %%
imp1 = SimpleImputer(strategy='mean').set_output(transform='pandas')

# %%
mean
# Out:
# S_No          4.500000
# Computer     75.333333
# Marketing    52.571429
# Engineer     85.625000
# dtype: float64

# %%
imp_1 = imp1.fit_transform(df1)

# %%
imp_1
# Out:
#      Yield  BiologicalMaterial01  BiologicalMaterial02  BiologicalMaterial03  \
# 0    38.00                  6.25                 49.58                 56.97
# 1    42.44                  8.01                 60.97                 67.48
# 2    42.03                  8.01                 60.97                 67.48
# 3    41.42                  8.01                 60.97                 67.48
# 4    42.49                  7.47                 63.33                 72.25
# ..     ...                   ...                   ...                   ...
# 171  39.66                  6.71                 56.32                 66.19
# 172  39.68                  6.87                 56.74                 66.61
# 173  42.23                  7.50                 58.41                 68.30
# 174  38.48                  7.53                 58.36                 69.25
# 175  39.49                  7.53                 58.36                 69.25
#
# ...

# %%
import pandas as pd
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
X = imp_1.drop('Yield',axis=1)
y = imp_1['Yield']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.3,random_state=24)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
accuracy = r2_score(Y_test,y_pred)

# %%
accuracy
# Out:
# 0.24181005955074442

# %% [markdown]
# # Imputing Median

# %%
# Out:
# S_No          4.5
# Computer     76.0
# Marketing    53.0
# Engineer     86.5
# dtype: float64

# %%
imp2 = SimpleImputer(strategy='median').set_output(transform = 'pandas')
# Set_output will give output in data frame , otherwise its array
imp_data_2 = imp2.fit_transform(df1)
type(imp_data_2)
imp_data_2
# Out:
#      Yield  BiologicalMaterial01  BiologicalMaterial02  BiologicalMaterial03  \
# 0    38.00                  6.25                 49.58                 56.97
# 1    42.44                  8.01                 60.97                 67.48
# 2    42.03                  8.01                 60.97                 67.48
# 3    41.42                  8.01                 60.97                 67.48
# 4    42.49                  7.47                 63.33                 72.25
# ..     ...                   ...                   ...                   ...
# 171  39.66                  6.71                 56.32                 66.19
# 172  39.68                  6.87                 56.74                 66.61
# 173  42.23                  7.50                 58.41                 68.30
# 174  38.48                  7.53                 58.36                 69.25
# 175  39.49                  7.53                 58.36                 69.25
#
# ...

# %%
X = imp_data_2.drop('Yield',axis=1)
y = imp_data_2['Yield']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.3,random_state=24)

# %%
lr2= LinearRegression()

# %%
lr2.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred_median = lr2.predict(X_test)

# %%
r2_median = r2_score(Y_test,y_pred_median)

# %%
r2_median
# Out:
# 0.2366120304070478
